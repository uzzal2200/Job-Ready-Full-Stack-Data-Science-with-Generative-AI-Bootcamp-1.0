# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

# %% [markdown]
# # Union(|)

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# # Intersection(&)

# %%
s1 & s2
# Out:
# {4, 5}

# %% [markdown]
# # Difference(-)

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s2 - s1
# Out:
# {6, 7, 8}

# %% [markdown]
# # Symmetric Difference(^)

# %%
s2 ^ s1
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# # Membership

# %%
s1 = {1,2,3,4,5}

1 not in s1
# Out:
# False

# %% [markdown]
# # Iteration

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
